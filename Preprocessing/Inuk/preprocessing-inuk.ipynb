# %%
import pandas as pd

# %%
COLAB = "/content/drive/MyDrive/Colab Notebooks"

data_path_1 = COLAB + "/bigstar-kogas/Inuk/용도별_판매전력량_추이_1997_2014.csv"
data_path_2 = COLAB + "/bigstar-kogas/Inuk/용도별_판매전력량_추이_2015_2021.csv"

df_97_14 = pd.read_csv(data_path_1, encoding="euc-kr")

df_15_21_raw = pd.read_csv(data_path_2, encoding="euc-kr")
df_15_21 = df_15_21_raw.drop(0, axis=0)

# %%
c1 = df_15_21["시점"] == 2015
c2 = df_15_21["시점"] == 2016

df_15_16 = df_15_21[c1 * c2]
df_15_16
# Out:
# Empty DataFrame
# Columns: [시점, 월별(1), 합계, 가정용, 공공용, 서비스업 및 기타, 농림어업, 광업, 제조업]
# Index: []
