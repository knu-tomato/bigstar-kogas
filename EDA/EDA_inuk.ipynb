# %% [markdown]
# # EDA
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## [1] 데이터 로딩
# ---

# %%
feature = pd.read_csv("../Data/use-data/data_tomato.csv", index_col=0)
target = pd.read_csv("../Data/use-data/target.csv", index_col=0)

data = pd.concat([feature, target], axis=1)

# %% [markdown]
# ## [2] 상관관계 행렬
# ---

# %%
data_corr = data.corr()
data_corr
# Out:
#                       TCL_AT    TCL_LT    TCL_HT  TEMP_EF_CAP  \
# TCL_AT              1.000000  0.981602  0.976676    -0.793539
# TCL_LT              0.981602  1.000000  0.929466    -0.845730
# TCL_HT              0.976676  0.929466  1.000000    -0.694848
# TEMP_EF_CAP        -0.793539 -0.845730 -0.694848     1.000000
# TEMP_EF_DONGNAM    -0.831270 -0.873102 -0.739788     0.958148
# TEMP_EF_DAEGYUNG   -0.829889 -0.883641 -0.733968     0.967380
# TEMP_EF_CHOONG     -0.838788 -0.883771 -0.749481     0.977956
# TEMP_EF_HONAM      -0.821678 -0.863138 -0.734818     0.964464
# TEMP_EF_MEAN       -0.817053 -0.866450 -0.721156     0.994682
# POWER_WATER         0.608421  0.619781  0.571275    -0.606986
# POWER_FIRE          0.212194  0.075715  0.363945     0.199490
# POWER_NUCLEAR       0.401963  0.300085  0.513588    -0.041450
# POWER_NAEYEON      -0.021854 -0.048044  0.012896     0.093471
# POWER_GROUP         0.176488  0.046715  0.317222     0.145131
# POWER_TRANS         0.379461  0.246405  0.515371     0.006337
# POWER_GAS           0.369153  0.243411  0.499218     0.079577
# POWER_JUNG         -0.505650 -0.445398 -0.544639     0.352793
# POWER_MOO          -0.100388 -0.059642 -0.133095     0.039206
# POWER_YOU           0.437087  0.305587  0.569936     0.017640
# POWER_LNG          -0.322059 -0.294555 -0.338121     0.272412
# ELEC_ALL            0.363098  0.218555  0.519089     0.092561
# ELEC_FAMILY         0.418818  0.284580  0.556872     0.049580
# ELEC_PUBLIC         0.271312  0.130303  0.430183     0.161154
# ELEC_SERVICE        0.229948  0.093739  0.386783     0.202884
# ELEC_CIVIL_SUM      0.283155  0.145378  0.437380     0.163033
# ELEC_ARGRI_FISHING  0.221047  0.075575  0.382076     0.175278
# ELEC_MINING         0.294045  0.185704  0.411430     0.022608
# ELEC_MANUFACT       0.436839  0.293010  0.586146     0.010040
# ELEC_INDSUM         0.422915  0.277909  0.574255     0.023150
# RV                 -0.084196 -0.071564 -0.093176     0.013621
# GAS_PRICE_IND       0.331416  0.227769  0.444737     0.020195
# OIL_PRICE           0.312355  0.220581  0.411548     0.001928
# QVA                 0.454298  0.306866  0.606904     0.005213
# CIVIL              -0.654744 -0.740967 -0.515668     0.877406
# IND                 0.132147 -0.013992  0.294810     0.287275
#
#                     TEMP_EF_DONGNAM  TEMP_EF_DAEGYUNG  TEMP_EF_CHOONG  \
# TCL_AT                    -0.831270         -0.829889       -0.838788
# TCL_LT                    -0.873102         -0.883641       -0.883771
# TCL_HT                    -0.739788         -0.733968       -0.749481
# TEMP_EF_CAP                0.958148          0.967380        0.977956
# TEMP_EF_DONGNAM            1.000000          0.985652        0.986853
# TEMP_EF_DAEGYUNG           0.985652          1.000000        0.989388
# TEMP_EF_CHOONG             0.986853          0.989388        1.000000
# TEMP_EF_HONAM              0.990027          0.980326        0.994336
# TEMP_EF_MEAN               0.980932          0.984968        0.993418
# POWER_WATER               -0.601664         -0.617588       -0.590145
# POWER_FIRE                 0.156210          0.170011        0.164230
# POWER_NUCLEAR             -0.075057         -0.059793       -0.061301
# POWER_NAEYEON              0.094885          0.069013        0.088413
# POWER_GROUP                0.103469          0.139455        0.109097
# POWER_TRANS               -0.039748         -0.006893       -0.041621
# POWER_GAS                  0.026115          0.041987        0.043087
# POWER_JUNG                 0.380376          0.342945        0.375562
# POWER_MOO                  0.042616          0.019639        0.056346
# POWER_YOU                 -0.036750         -0.014144       -0.020279
# POWER_LNG                  0.305973          0.264822        0.308933
# ELEC_ALL                   0.045542          0.068354        0.054994
# ELEC_FAMILY               -0.010292          0.011576        0.008741
# ELEC_PUBLIC                0.119506          0.137850        0.131250
# ELEC_SERVICE               0.167734          0.180437        0.180387
# ELEC_CIVIL_SUM             0.120739          0.136459        0.134978
# ELEC_ARGRI_FISHING         0.118574          0.156760        0.137152
# ELEC_MINING                0.001296          0.018494       -0.007189
# ELEC_MANUFACT             -0.038547         -0.011086       -0.035100
# ELEC_INDSUM               -0.026347          0.002137       -0.021747
# RV                         0.027286          0.032731        0.021992
# GAS_PRICE_IND             -0.016393         -0.000142       -0.004558
# OIL_PRICE                 -0.029070         -0.021794       -0.020194
# QVA                       -0.043879         -0.012720       -0.038716
# CIVIL                      0.872404          0.873698        0.886714
# IND                        0.240847          0.275337        0.260922
#
#                     TEMP_EF_HONAM  TEMP_EF_MEAN  POWER_WATER  ...  \
# TCL_AT                  -0.821678     -0.817053     0.608421  ...
# TCL_LT                  -0.863138     -0.866450     0.619781  ...
# TCL_HT                  -0.734818     -0.721156     0.571275  ...
# TEMP_EF_CAP              0.964464      0.994682    -0.606986  ...
# TEMP_EF_DONGNAM          0.990027      0.980932    -0.601664  ...
# TEMP_EF_DAEGYUNG         0.980326      0.984968    -0.617588  ...
# TEMP_EF_CHOONG           0.994336      0.993418    -0.590145  ...
# TEMP_EF_HONAM            1.000000      0.985222    -0.561499  ...
# TEMP_EF_MEAN             0.985222      1.000000    -0.605077  ...
# POWER_WATER             -0.561499     -0.605077     1.000000  ...
# POWER_FIRE               0.174470      0.186433     0.174997  ...
# POWER_NUCLEAR           -0.053059     -0.051030     0.235293  ...
# POWER_NAEYEON            0.099830      0.092608     0.118712  ...
# POWER_GROUP              0.110523      0.132367     0.133370  ...
# POWER_TRANS             -0.033681     -0.011024     0.208244  ...
# POWER_GAS                0.056414      0.063767     0.248857  ...
# POWER_JUNG               0.378491      0.364348    -0.413343  ...
# POWER_MOO                0.058431      0.043081     0.030109  ...
# POWER_YOU               -0.009065      0.001013     0.291823  ...
# POWER_LNG                0.328803      0.289468    -0.058329  ...
# ELEC_ALL                 0.067612      0.078214     0.245742  ...
# ELEC_FAMILY              0.026043      0.032098     0.293971  ...
# ELEC_PUBLIC              0.145576      0.150216     0.230714  ...
# ELEC_SERVICE             0.198438      0.195396     0.169356  ...
# ELEC_CIVIL_SUM           0.152616      0.152636     0.208575  ...
# ELEC_ARGRI_FISHING       0.140535      0.159854     0.170103  ...
# ELEC_MINING             -0.004649      0.012832     0.150735  ...
# ELEC_MANUFACT           -0.027354     -0.007452     0.277135  ...
# ELEC_INDSUM             -0.014303      0.005711     0.270458  ...
# RV                       0.027808      0.019444    -0.105141  ...
# GAS_PRICE_IND           -0.000508      0.008967     0.262966  ...
# OIL_PRICE               -0.016304     -0.008443     0.272395  ...
# QVA                     -0.032695     -0.012021     0.258264  ...
# CIVIL                    0.887378      0.886776    -0.420026  ...
# IND                      0.259936      0.276981     0.125716  ...
#
#                     ELEC_ARGRI_FISHING  ELEC_MINING  ELEC_MANUFACT  \
# TCL_AT                        0.221047     0.294045       0.436839
# TCL_LT                        0.075575     0.185704       0.293010
# TCL_HT                        0.382076     0.411430       0.586146
# TEMP_EF_CAP                   0.175278     0.022608       0.010040
# TEMP_EF_DONGNAM               0.118574     0.001296      -0.038547
# TEMP_EF_DAEGYUNG              0.156760     0.018494      -0.011086
# TEMP_EF_CHOONG                0.137152    -0.007189      -0.035100
# TEMP_EF_HONAM                 0.140535    -0.004649      -0.027354
# TEMP_EF_MEAN                  0.159854     0.012832      -0.007452
# POWER_WATER                   0.170103     0.150735       0.277135
# POWER_FIRE                    0.846219     0.718667       0.912744
# POWER_NUCLEAR                 0.595527     0.712715       0.749416
# POWER_NAEYEON                 0.151402     0.303771       0.263678
# POWER_GROUP                   0.870127     0.441242       0.756147
# POWER_TRANS                   0.869083     0.493021       0.826225
# POWER_GAS                     0.827669     0.712821       0.918814
# POWER_JUNG                   -0.416028    -0.302687      -0.452758
# POWER_MOO                    -0.227270     0.107562      -0.075182
# POWER_YOU                     0.856751     0.720269       0.943428
# POWER_LNG                    -0.108798    -0.083215      -0.118372
# ELEC_ALL                      0.922370     0.751997       0.977695
# ELEC_FAMILY                   0.885087     0.669059       0.910085
# ELEC_PUBLIC                   0.926417     0.723764       0.949930
# ELEC_SERVICE                  0.874364     0.700131       0.890659
# ELEC_CIVIL_SUM                0.892559     0.702981       0.911980
# ELEC_ARGRI_FISHING            1.000000     0.622514       0.898680
# ELEC_MINING                   0.622514     1.000000       0.771153
# ELEC_MANUFACT                 0.898680     0.771153       1.000000
# ELEC_INDSUM                   0.912890     0.767293       0.999431
# RV                            0.036596    -0.147501      -0.075377
# GAS_PRICE_IND                 0.610467     0.685967       0.788230
# OIL_PRICE                     0.495484     0.651148       0.694545
# QVA                           0.900345     0.765217       0.983966
# CIVIL                         0.450613     0.282141       0.306123
# IND                           0.852336     0.732399       0.914618
#
#                     ELEC_INDSUM        RV  GAS_PRICE_IND  OIL_PRICE       QVA  \
# TCL_AT                 0.422915 -0.084196       0.331416   0.312355  0.454298
# TCL_LT                 0.277909 -0.071564       0.227769   0.220581  0.306866
# TCL_HT                 0.574255 -0.093176       0.444737   0.411548  0.606904
# TEMP_EF_CAP            0.023150  0.013621       0.020195   0.001928  0.005213
# TEMP_EF_DONGNAM       -0.026347  0.027286      -0.016393  -0.029070 -0.043879
# TEMP_EF_DAEGYUNG       0.002137  0.032731      -0.000142  -0.021794 -0.012720
# TEMP_EF_CHOONG        -0.021747  0.021992      -0.004558  -0.020194 -0.038716
# TEMP_EF_HONAM         -0.014303  0.027808      -0.000508  -0.016304 -0.032695
# TEMP_EF_MEAN           0.005711  0.019444       0.008967  -0.008443 -0.012021
# POWER_WATER            0.270458 -0.105141       0.262966   0.272395  0.258264
# POWER_FIRE             0.914338 -0.179041       0.772448   0.725376  0.893882
# POWER_NUCLEAR          0.743577 -0.080903       0.725190   0.637768  0.781105
# POWER_NAEYEON          0.257341 -0.172365       0.363575   0.406930  0.205132
# POWER_GROUP            0.769927  0.125204       0.307295   0.198136  0.747862
# POWER_TRANS            0.834932  0.141362       0.393202   0.269153  0.823239
# POWER_GAS              0.918467 -0.143815       0.788864   0.721663  0.904817
# POWER_JUNG            -0.452976  0.054259      -0.263478  -0.246526 -0.472616
# POWER_MOO             -0.086803 -0.021516       0.331688   0.300305 -0.139720
# POWER_YOU              0.943552 -0.142263       0.784488   0.714991  0.941459
# POWER_LNG             -0.118452 -0.240187       0.015876   0.149592 -0.157077
# ELEC_ALL               0.980559 -0.103361       0.784390   0.702774  0.979439
# ELEC_FAMILY            0.914668 -0.123802       0.732358   0.667987  0.932844
# ELEC_PUBLIC            0.955048 -0.096375       0.760365   0.680514  0.948051
# ELEC_SERVICE           0.896021 -0.147113       0.749142   0.690983  0.912174
# ELEC_CIVIL_SUM         0.917184 -0.137222       0.754576   0.691772  0.931342
# ELEC_ARGRI_FISHING     0.912890  0.036596       0.610467   0.495484  0.900345
# ELEC_MINING            0.767293 -0.147501       0.685967   0.651148  0.765217
# ELEC_MANUFACT          0.999431 -0.075377       0.788230   0.694545  0.983966
# ELEC_INDSUM            1.000000 -0.067616       0.780511   0.684659  0.984701
# RV                    -0.067616  1.000000      -0.142401  -0.514979 -0.101010
# GAS_PRICE_IND          0.780511 -0.142401       1.000000   0.903896  0.773294
# OIL_PRICE              0.684659 -0.514979       0.903896   1.000000  0.688464
# QVA                    0.984701 -0.101010       0.773294   0.688464  1.000000
# CIVIL                  0.319953 -0.043915       0.279592   0.246144  0.309064
# IND                    0.916622 -0.166224       0.834184   0.769863  0.898529
#
#                        CIVIL       IND
# TCL_AT             -0.654744  0.132147
# TCL_LT             -0.740967 -0.013992
# TCL_HT             -0.515668  0.294810
# TEMP_EF_CAP         0.877406  0.287275
# TEMP_EF_DONGNAM     0.872404  0.240847
# TEMP_EF_DAEGYUNG    0.873698  0.275337
# TEMP_EF_CHOONG      0.886714  0.260922
# TEMP_EF_HONAM       0.887378  0.259936
# TEMP_EF_MEAN        0.886776  0.276981
# POWER_WATER        -0.420026  0.125716
# POWER_FIRE          0.494229  0.930535
# POWER_NUCLEAR       0.278940  0.714873
# POWER_NAEYEON       0.159015  0.294282
# POWER_GROUP         0.344741  0.658649
# POWER_TRANS         0.201696  0.669871
# POWER_GAS           0.389385  0.888670
# POWER_JUNG          0.251030 -0.268436
# POWER_MOO           0.053002  0.056575
# POWER_YOU           0.334125  0.885779
# POWER_LNG           0.255683  0.055362
# ELEC_ALL            0.417276  0.924607
# ELEC_FAMILY         0.359507  0.843233
# ELEC_PUBLIC         0.493577  0.924640
# ELEC_SERVICE        0.550681  0.891098
# ELEC_CIVIL_SUM      0.503671  0.893102
# ELEC_ARGRI_FISHING  0.450613  0.852336
# ELEC_MINING         0.282141  0.732399
# ELEC_MANUFACT       0.306123  0.914618
# ELEC_INDSUM         0.319953  0.916622
# RV                 -0.043915 -0.166224
# GAS_PRICE_IND       0.279592  0.834184
# OIL_PRICE           0.246144  0.769863
# QVA                 0.309064  0.898529
# CIVIL               1.000000  0.570052
# IND                 0.570052  1.000000
#
# [35 rows x 35 columns]

# %%
cg = sns.clustermap(data_corr, cmap="YlGnBu", linewidths=0.1)
plt.setp(cg.ax_heatmap.yaxis.get_majorticklabels(), rotation=0)

cg

# %% [markdown]
# ## [3] 유형별로 데이터 확인
# ---

# %%
data.columns
# Out:
# Index(['TCL_AT', 'TCL_LT', 'TCL_HT', 'TEMP_EF_CAP', 'TEMP_EF_DONGNAM',
#        'TEMP_EF_DAEGYUNG', 'TEMP_EF_CHOONG', 'TEMP_EF_HONAM', 'TEMP_EF_MEAN',
#        'POWER_WATER', 'POWER_FIRE', 'POWER_NUCLEAR', 'POWER_NAEYEON',
#        'POWER_GROUP', 'POWER_TRANS', 'POWER_GAS', 'POWER_JUNG', 'POWER_MOO',
#        'POWER_YOU', 'POWER_LNG', 'ELEC_ALL', 'ELEC_FAMILY', 'ELEC_PUBLIC',
#        'ELEC_SERVICE', 'ELEC_CIVIL_SUM', 'ELEC_ARGRI_FISHING', 'ELEC_MINING',
#        'ELEC_MANUFACT', 'ELEC_INDSUM', 'RV', 'GAS_PRICE_IND', 'OIL_PRICE',
#        'QVA', 'CIVIL', 'IND'],
#       dtype='object')

# %%
temp_cols = [col for col in data.columns if "TEMP" in col]
tcl_cols = [col for col in data.columns if "TCL" in col]
power_cols = [col for col in data.columns if "POWER" in col]
elec_cols = [col for col in data.columns if "ELEC" in col]

data_temp = data[temp_cols]
data_tcl = data[tcl_cols]
data_power = data[power_cols]
data_elec = data[elec_cols]

data_qva = data["QVA"]
data_rv = data["RV"]
data_civil = data["CIVIL"]
data_ind = data["IND"]

# %%
data_power.shape
# Out:
# (300, 11)

# %%
def draw_plots(data, figsize):
    len = data.shape[1]
    data_cols = data.columns
    date = pd.to_datetime(data.index)

    cols = 4
    rows = (len // 5) + 1

    plt.figure(figsize=figsize)

    for i, data_col in zip(range(1, len), data_cols):
        plt.subplot(rows, cols, i)
        plt.plot(date, data[data_col])
        plt.title(data_col)
    
    plt.show()

# %%
draw_plots(data_temp, (18, 15))

# %%
draw_plots(data_tcl, (15, 5))

# %%
draw_plots(data_elec, (18, 15))

# %%
draw_plots(data_power, (18, 15))
